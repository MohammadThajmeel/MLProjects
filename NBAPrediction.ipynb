# %%
import pandas as pd

# %%
df = pd.read_csv("nba_games.csv", index_col=0)

# %%
df
# Out:
#         mp  mp.1  fg  fga    fg%  3p  3pa    3p%  ft  fta  ...  tov%_max_opp  \
# 0      240   240  39   81  0.481   6   20  0.300  14   18  ...          22.8
# 1      240   240  36  100  0.360   7   31  0.226  16   19  ...          50.0
# 2      240   240  37   85  0.435   8   19  0.421  17   23  ...          20.0
# 3      240   240  41   89  0.461   8   21  0.381  17   19  ...          28.6
# 4      240   240  27   86  0.314   6   26  0.231  15   20  ...          16.8
# ...    ...   ...  ..  ...    ...  ..  ...    ...  ..  ...  ...           ...
# 17767  240   240  35   81  0.432  11   26  0.423  27   36  ...          34.2
# 17768  240   240  37   74  0.500  13   25  0.520  26   37  ...          25.0
# 17769  240   240  42   89  0.472  14   33  0.424  10   20  ...          25.6
# 17770  240   240  41   85  0.482   9   26  0.346  26   30  ...          27.7
# 17771  240   240  33   85  0.388  12   44  0.273  28   34  ...          51.5
#
#        usg%_max_opp  ortg_max_opp  drtg_max_opp  team_opp  total_opp  \
# 0              29.0           178           111       DAL         95
# 1              32.6           152           111       ATL         98
# 2              30.9           148           116       SAS        107
# 3              30.9           138           118       MIN         99
# 4              30.9           157            90       MEM         92
# ...             ...           ...           ...       ...        ...
# 17767          33.7           160           118       OKC         92
# 17768          30.0           139           129       ORL        108
# 17769          29.9           175           126       LAC        113
# 17770          27.1           150           126       MIA        106
# 17771          36.2           141           114       BOS        117
#
#        home_opp  season        date    won
# 0             1    2016   12/9/2015   True
# 1             0    2016   12/9/2015  False
# 2             1    2018  10/18/2017  False
# 3             0    2018  10/18/2017   True
# 4             1    2021   4/30/2021  False
# ...         ...     ...         ...    ...
# 17767         0    2019  10/19/2018   True
# 17768         1    2017  12/14/2016   True
# 17769         0    2017  12/14/2016  False
# 17770         1    2020   9/19/2020   True
# 17771         0    2020   9/19/2020  False
#
# [17772 rows x 150 columns]

# %%
df = df.sort_values("date")

# %%
df = df.reset_index(drop=True)

# %%
del df["mp.1"]
del df["mp_opp.1"]
del df["index_opp"]

# %%
def add_target(group):
    group["target"] = group["won"].shift(-1)
    return group

df = df.groupby("team", group_keys=False).apply(add_target)
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_22484\3080091488.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby("team", group_keys=False).apply(add_target)

# %%
df[df["team"] == "WAS"]
# Out:
#         mp  fg  fga    fg%  3p  3pa    3p%  ft  fta    ft%  ...  usg%_max_opp  \
# 8      240  43   92  0.467   8   26  0.308   9   10  0.900  ...          44.9
# 38     240  33   87  0.379   9   31  0.290  26   31  0.839  ...          40.4
# 61     240  49   89  0.551  16   33  0.485  16   21  0.762  ...          34.6
# 76     240  46   87  0.529   6   27  0.222  21   26  0.808  ...          37.6
# 105    240  42   83  0.506  11   22  0.500   6    9  0.667  ...          26.3
# ...    ...  ..  ...    ...  ..  ...    ...  ..  ...    ...  ...           ...
# 17544  240  40   88  0.455   9   31  0.290  21   27  0.778  ...          33.1
# 17615  240  41   94  0.436  11   30  0.367   7   13  0.538  ...          31.4
# 17641  240  36   85  0.424   7   21  0.333  19   24  0.792  ...          35.8
# 17674  240  38   90  0.422  10   27  0.370  21   23  0.913  ...          28.1
# 17698  240  38   92  0.413   9   36  0.250  18   22  0.818  ...          25.6
#
#        ortg_max_opp  drtg_max_opp  team_opp  total_opp  home_opp  season  \
# 8               200           120       ORL         91         0    2016
# 38              197           110       ORL        122         0    2020
# 61              167           130       MIN        109         1    2021
# 76              236           121       CHI        120         0    2022
# 105             137           108       CHI         99         0    2017
# ...             ...           ...       ...        ...       ...     ...
# 17544           165           115       BRK        118         1    2020
# 17615           145           109       IND        111         0    2020
# 17641           164           106       PHI        107         0    2020
# 17674           192           116       NOP        118         1    2020
# 17698           242           114       OKC        121         1    2020
#
#             date    won  target
# 8       1/1/2016   True   False
# 38      1/1/2020  False    True
# 61      1/1/2021   True   False
# 76      1/1/2022  False    True
# 105    1/10/2017   True   False
# ...          ...    ...     ...
# 17544   8/2/2020  False   False
# 17615   8/3/2020  False   False
# 17641   8/5/2020  False   False
# 17674   8/7/2020  False   False
# 17698   8/9/2020  False     NaN
#
# [580 rows x 148 columns]

# %%
df["target"][pd.isnull(df["target"])] = 2
df["target"] = df["target"].astype(int, errors="ignore")
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_22484\2793819745.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["target"][pd.isnull(df["target"])] = 2
# C:\Users\moham\AppData\Local\Temp\ipykernel_22484\2793819745.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["target"][pd.isnull(df["target"])] = 2

# %%
df["won"].value_counts()
# Out:
# won
# True     8886
# False    8886
# Name: count, dtype: int64

# %%
df["target"].value_counts()
# Out:
# target
# 1    8873
# 0    8869
# 2      30
# Name: count, dtype: int64

# %%
nulls = pd.isnull(df).sum()

# %%
nulls = nulls[nulls > 0]

# %%
valid_columns = df.columns[~df.columns.isin(nulls.index)]

# %%
valid_columns
# Out:
# Index(['mp', 'fg', 'fga', 'fg%', '3p', '3pa', '3p%', 'ft', 'fta', 'ft%',
#        ...
#        'usg%_max_opp', 'ortg_max_opp', 'drtg_max_opp', 'team_opp', 'total_opp',
#        'home_opp', 'season', 'date', 'won', 'target'],
#       dtype='object', length=142)

# %%
df = df[valid_columns].copy()

# %%
df
# Out:
#         mp  fg  fga    fg%  3p  3pa    3p%  ft  fta    ft%  ...  usg%_max_opp  \
# 0      240  36   91  0.396  15   33  0.455  17   18  0.944  ...          30.6
# 1      240  33   87  0.379   5   16  0.313  22   29  0.759  ...          40.4
# 2      240  39   85  0.459  10   16  0.625  20   25  0.800  ...          39.6
# 3      240  31   84  0.369   6   19  0.316  13   17  0.765  ...          42.7
# 4      240  31   84  0.369   4   24  0.167  18   25  0.720  ...          30.6
# ...    ...  ..  ...    ...  ..  ...    ...  ..  ...    ...  ...           ...
# 17767  240  38   81  0.469  12   30  0.400  14   14  1.000  ...          37.2
# 17768  240  27   68  0.397   9   27  0.333  22   26  0.846  ...          34.3
# 17769  240  33   79  0.418   8   28  0.286  22   30  0.733  ...          35.5
# 17770  290  44  101  0.436  19   47  0.404  18   25  0.720  ...          32.5
# 17771  290  44  100  0.440  19   46  0.413  15   18  0.833  ...          23.7
#
#        ortg_max_opp  drtg_max_opp  team_opp  total_opp  home_opp  season  \
# 0               174           130       CHO         94         0    2016
# 1               150           105       PHI         84         0    2016
# 2               171           132       NYK         81         0    2016
# 3               195           102       CHI        108         1    2016
# 4               164           100       LAL         93         1    2016
# ...             ...           ...       ...        ...       ...     ...
# 17767           151           123       LAL        112         0    2020
# 17768           143           106       LAC         96         0    2020
# 17769           162           117       DEN         85         1    2020
# 17770           300           120       BOS        122         1    2020
# 17771           149           117       TOR        125         0    2020
#
#            date    won  target
# 0      1/1/2016   True       1
# 1      1/1/2016   True       0
# 2      1/1/2016   True       0
# 3      1/1/2016  False       0
# 4      1/1/2016  False       1
# ...         ...    ...     ...
# 17767  9/8/2020  False       2
# 17768  9/9/2020  False       2
# 17769  9/9/2020   True       2
# 17770  9/9/2020   True       2
# 17771  9/9/2020  False       2
#
# [17772 rows x 142 columns]

# %%
from sklearn.linear_model import RidgeClassifier
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.model_selection import TimeSeriesSplit

rr = RidgeClassifier(alpha=1)

split = TimeSeriesSplit(n_splits=3)

sfs = SequentialFeatureSelector(rr, 
                                n_features_to_select=30, 
                                direction="forward",
                                cv=split,
                                n_jobs=1
                               )

# %%
removed_columns = ["season", "date", "won", "target", "team", "team_opp"]
selected_columns = df.columns[~df.columns.isin(removed_columns)]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df[selected_columns] = scaler.fit_transform(df[selected_columns])

# %%
df
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.0  0.386364  0.455882  0.303828  0.517241  0.439394  0.540380
# 1      0.0  0.318182  0.397059  0.263158  0.172414  0.181818  0.371734
# 2      0.0  0.454545  0.367647  0.454545  0.344828  0.181818  0.742280
# 3      0.0  0.272727  0.352941  0.239234  0.206897  0.227273  0.375297
# 4      0.0  0.272727  0.352941  0.239234  0.137931  0.303030  0.198337
# ...    ...       ...       ...       ...       ...       ...       ...
# 17767  0.0  0.431818  0.308824  0.478469  0.413793  0.393939  0.475059
# 17768  0.0  0.181818  0.117647  0.306220  0.310345  0.348485  0.395487
# 17769  0.0  0.318182  0.279412  0.356459  0.275862  0.363636  0.339667
# 17770  0.5  0.568182  0.602941  0.399522  0.655172  0.651515  0.479810
# 17771  0.5  0.568182  0.588235  0.409091  0.655172  0.636364  0.490499
#
#              ft       fta       ft%  ...  usg%_max_opp  ortg_max_opp  \
# 0      0.372093  0.269841  0.934656  ...      0.109114      0.402844
# 1      0.488372  0.444444  0.718786  ...      0.234917      0.289100
# 2      0.441860  0.380952  0.766628  ...      0.224647      0.388626
# 3      0.279070  0.253968  0.725788  ...      0.264442      0.502370
# 4      0.395349  0.380952  0.673279  ...      0.109114      0.355450
# ...         ...       ...       ...  ...           ...           ...
# 17767  0.302326  0.206349  1.000000  ...      0.193838      0.293839
# 17768  0.488372  0.396825  0.820303  ...      0.156611      0.255924
# 17769  0.488372  0.460317  0.688448  ...      0.172015      0.345972
# 17770  0.395349  0.380952  0.673279  ...      0.133504      1.000000
# 17771  0.325581  0.269841  0.805134  ...      0.020539      0.284360
#
#        drtg_max_opp  team_opp  total_opp  home_opp  season      date    won  \
# 0          0.623529       CHO   0.288462       0.0    2016  1/1/2016   True
# 1          0.329412       PHI   0.192308       0.0    2016  1/1/2016   True
# 2          0.647059       NYK   0.163462       0.0    2016  1/1/2016   True
# 3          0.294118       CHI   0.423077       1.0    2016  1/1/2016  False
# 4          0.270588       LAL   0.278846       1.0    2016  1/1/2016  False
# ...             ...       ...        ...       ...     ...       ...    ...
# 17767      0.541176       LAL   0.461538       0.0    2020  9/8/2020  False
# 17768      0.341176       LAC   0.307692       0.0    2020  9/9/2020  False
# 17769      0.470588       DEN   0.201923       1.0    2020  9/9/2020   True
# 17770      0.505882       BOS   0.557692       1.0    2020  9/9/2020   True
# 17771      0.470588       TOR   0.586538       0.0    2020  9/9/2020  False
#
#        target
# 0           1
# 1           0
# 2           0
# 3           0
# 4           1
# ...       ...
# 17767       2
# 17768       2
# 17769       2
# 17770       2
# 17771       2
#
# [17772 rows x 142 columns]

# %%
sfs.fit(df[selected_columns], df["target"])
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=RidgeClassifier(alpha=1),
#                           n_features_to_select=30, n_jobs=1)

# %%
predictors = list(selected_columns[sfs.get_support()])

# %%
predictors
# Out:
# ['mp',
#  'fga',
#  'efg%',
#  'ast%',
#  'usg%',
#  'fg_max',
#  'fga_max',
#  '3pa_max',
#  'ft%_max',
#  'orb_max',
#  'drb_max',
#  'ftr_max',
#  'orb%_max',
#  'drb%_max',
#  'mp_opp',
#  'fga_opp',
#  'trb_opp',
#  'stl_opp',
#  'pf_opp',
#  'ast%_opp',
#  'blk%_opp',
#  'usg%_opp',
#  '3p_max_opp',
#  '3p%_max_opp',
#  'ft%_max_opp',
#  'ast_max_opp',
#  'trb%_max_opp',
#  'blk%_max_opp',
#  'tov%_max_opp',
#  'ortg_max_opp']

# %%
def backtest(data, model, predictors, start=2, step=1):
    all_predictions = []
    
    seasons = sorted(data["season"].unique())
    
    for i in range(start, len(seasons), step):
        season = seasons[i]
        train = data[data["season"] < season]
        test = data[data["season"] == season]
        
        model.fit(train[predictors], train["target"])
        
        preds = model.predict(test[predictors])
        preds = pd.Series(preds, index=test.index)
        combined = pd.concat([test["target"], preds], axis=1)
        combined.columns = ["actual", "prediction"]
        
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions = backtest(df, rr, predictors)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(predictions["actual"], predictions["prediction"])
# Out:
# 0.5095831336847149

# %%
df.groupby(["home"]).apply(lambda x: x[x["won"] == 1].shape[0] / x.shape[0])
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_22484\330557953.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df.groupby(["home"]).apply(lambda x: x[x["won"] == 1].shape[0] / x.shape[0])
# home
# 0.0    0.428314
# 1.0    0.571686
# dtype: float64

# %%
df
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.0  0.386364  0.455882  0.303828  0.517241  0.439394  0.540380
# 1      0.0  0.318182  0.397059  0.263158  0.172414  0.181818  0.371734
# 2      0.0  0.454545  0.367647  0.454545  0.344828  0.181818  0.742280
# 3      0.0  0.272727  0.352941  0.239234  0.206897  0.227273  0.375297
# 4      0.0  0.272727  0.352941  0.239234  0.137931  0.303030  0.198337
# ...    ...       ...       ...       ...       ...       ...       ...
# 17767  0.0  0.431818  0.308824  0.478469  0.413793  0.393939  0.475059
# 17768  0.0  0.181818  0.117647  0.306220  0.310345  0.348485  0.395487
# 17769  0.0  0.318182  0.279412  0.356459  0.275862  0.363636  0.339667
# 17770  0.5  0.568182  0.602941  0.399522  0.655172  0.651515  0.479810
# 17771  0.5  0.568182  0.588235  0.409091  0.655172  0.636364  0.490499
#
#              ft       fta       ft%  ...  usg%_max_opp  ortg_max_opp  \
# 0      0.372093  0.269841  0.934656  ...      0.109114      0.402844
# 1      0.488372  0.444444  0.718786  ...      0.234917      0.289100
# 2      0.441860  0.380952  0.766628  ...      0.224647      0.388626
# 3      0.279070  0.253968  0.725788  ...      0.264442      0.502370
# 4      0.395349  0.380952  0.673279  ...      0.109114      0.355450
# ...         ...       ...       ...  ...           ...           ...
# 17767  0.302326  0.206349  1.000000  ...      0.193838      0.293839
# 17768  0.488372  0.396825  0.820303  ...      0.156611      0.255924
# 17769  0.488372  0.460317  0.688448  ...      0.172015      0.345972
# 17770  0.395349  0.380952  0.673279  ...      0.133504      1.000000
# 17771  0.325581  0.269841  0.805134  ...      0.020539      0.284360
#
#        drtg_max_opp  team_opp  total_opp  home_opp  season      date    won  \
# 0          0.623529       CHO   0.288462       0.0    2016  1/1/2016   True
# 1          0.329412       PHI   0.192308       0.0    2016  1/1/2016   True
# 2          0.647059       NYK   0.163462       0.0    2016  1/1/2016   True
# 3          0.294118       CHI   0.423077       1.0    2016  1/1/2016  False
# 4          0.270588       LAL   0.278846       1.0    2016  1/1/2016  False
# ...             ...       ...        ...       ...     ...       ...    ...
# 17767      0.541176       LAL   0.461538       0.0    2020  9/8/2020  False
# 17768      0.341176       LAC   0.307692       0.0    2020  9/9/2020  False
# 17769      0.470588       DEN   0.201923       1.0    2020  9/9/2020   True
# 17770      0.505882       BOS   0.557692       1.0    2020  9/9/2020   True
# 17771      0.470588       TOR   0.586538       0.0    2020  9/9/2020  False
#
#        target
# 0           1
# 1           0
# 2           0
# 3           0
# 4           1
# ...       ...
# 17767       2
# 17768       2
# 17769       2
# 17770       2
# 17771       2
#
# [17772 rows x 142 columns]

# %%
df_rolling = df[list(selected_columns) + ["won", "team", "season"]]

def find_team_averages(team):
    rolling = team.rolling(10).mean(float)
    return rolling

df_rolling = df_rolling.groupby(["team", "season"], group_keys=False).apply(find_team_averages)
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_22484\2973567071.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_rolling = df_rolling.groupby(["team", "season"], group_keys=False).apply(find_team_averages)

# %%
df_rolling
# Out:
#           mp        fg       fga       fg%        3p       3pa       3p%  \
# 0        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ...      ...       ...       ...       ...       ...       ...       ...
# 17767  0.000  0.384091  0.335294  0.395694  0.568966  0.642424  0.426722
# 17768  0.000  0.427273  0.308824  0.474880  0.355172  0.410606  0.393705
# 17769  0.000  0.472727  0.370588  0.474641  0.396552  0.424242  0.427672
# 17770  0.050  0.386364  0.363235  0.375598  0.437931  0.528788  0.384561
# 17771  0.075  0.463636  0.373529  0.464354  0.417241  0.490909  0.391805
#
#              ft       fta       ft%  ...  ast%_max_opp  stl%_max_opp  \
# 0           NaN       NaN       NaN  ...           NaN           NaN
# 1           NaN       NaN       NaN  ...           NaN           NaN
# 2           NaN       NaN       NaN  ...           NaN           NaN
# 3           NaN       NaN       NaN  ...           NaN           NaN
# 4           NaN       NaN       NaN  ...           NaN           NaN
# ...         ...       ...       ...  ...           ...           ...
# 17767  0.404651  0.357143  0.758460  ...      0.325459        0.0631
# 17768  0.418605  0.357143  0.783314  ...      0.471904        0.0577
# 17769  0.393023  0.341270  0.767561  ...      0.300229        0.0550
# 17770  0.367442  0.333333  0.731155  ...      0.313876        0.0743
# 17771  0.430233  0.357143  0.798016  ...      0.230619        0.0375
#
#        blk%_max_opp  tov%_max_opp  usg%_max_opp  ortg_max_opp  drtg_max_opp  \
# 0               NaN           NaN           NaN           NaN           NaN
# 1               NaN           NaN           NaN           NaN           NaN
# 2               NaN           NaN           NaN           NaN           NaN
# 3               NaN           NaN           NaN           NaN           NaN
# 4               NaN           NaN           NaN           NaN           NaN
# ...             ...           ...           ...           ...           ...
# 17767        0.1709      0.525262      0.155199      0.373934      0.456471
# 17768        0.0611      0.451887      0.226444      0.453555      0.492941
# 17769        0.0935      0.385010      0.175610      0.428910      0.536471
# 17770        0.0951      0.508491      0.101027      0.491943      0.372941
# 17771        0.0860      0.239623      0.072401      0.400948      0.497647
#
#        total_opp  home_opp  season
# 0            NaN       NaN     NaN
# 1            NaN       NaN     NaN
# 2            NaN       NaN     NaN
# 3            NaN       NaN     NaN
# 4            NaN       NaN     NaN
# ...          ...       ...     ...
# 17767   0.423077       0.6  2020.0
# 17768   0.429808       0.6  2020.0
# 17769   0.425000       0.5  2020.0
# 17770   0.399038       0.4  2020.0
# 17771   0.434615       0.4  2020.0
#
# [17772 rows x 137 columns]

# %%
rolling_cols = [f"{col}_10" for col in df_rolling.columns]
df_rolling.columns = rolling_cols
df = pd.concat([df, df_rolling], axis=1)

# %%
df = df.dropna()

# %%
df
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 1385   0.0  0.477273  0.397059  0.456938  0.344828  0.439394  0.359857
# 1489   0.0  0.204545  0.323529  0.172249  0.310345  0.409091  0.344418
# 1515   0.0  0.454545  0.250000  0.566986  0.482759  0.469697  0.475059
# 1542   0.0  0.386364  0.426471  0.322967  0.448276  0.530303  0.395487
# 1596   0.0  0.545455  0.485294  0.461722  0.275862  0.333333  0.365796
# ...    ...       ...       ...       ...       ...       ...       ...
# 17767  0.0  0.431818  0.308824  0.478469  0.413793  0.393939  0.475059
# 17768  0.0  0.181818  0.117647  0.306220  0.310345  0.348485  0.395487
# 17769  0.0  0.318182  0.279412  0.356459  0.275862  0.363636  0.339667
# 17770  0.5  0.568182  0.602941  0.399522  0.655172  0.651515  0.479810
# 17771  0.5  0.568182  0.588235  0.409091  0.655172  0.636364  0.490499
#
#              ft       fta       ft%  ...  ast%_max_opp_10  stl%_max_opp_10  \
# 1385   0.348837  0.269841  0.870478  ...         0.383486           0.0534
# 1489   0.720930  0.571429  0.842474  ...         0.561239           0.0459
# 1515   0.488372  0.428571  0.750292  ...         0.324427           0.0718
# 1542   0.279070  0.285714  0.631272  ...         0.335436           0.0379
# 1596   0.255814  0.285714  0.570595  ...         0.271101           0.0625
# ...         ...       ...       ...  ...              ...              ...
# 17767  0.302326  0.206349  1.000000  ...         0.325459           0.0631
# 17768  0.488372  0.396825  0.820303  ...         0.471904           0.0577
# 17769  0.488372  0.460317  0.688448  ...         0.300229           0.0550
# 17770  0.395349  0.380952  0.673279  ...         0.313876           0.0743
# 17771  0.325581  0.269841  0.805134  ...         0.230619           0.0375
#
#        blk%_max_opp_10  tov%_max_opp_10  usg%_max_opp_10  ortg_max_opp_10  \
# 1385            0.0613         0.467925         0.146598         0.406161
# 1489            0.1454         0.404088         0.124519         0.559242
# 1515            0.0852         0.299895         0.152246         0.384834
# 1542            0.1445         0.423166         0.135430         0.306635
# 1596            0.0834         0.377254         0.113607         0.356872
# ...                ...              ...              ...              ...
# 17767           0.1709         0.525262         0.155199         0.373934
# 17768           0.0611         0.451887         0.226444         0.453555
# 17769           0.0935         0.385010         0.175610         0.428910
# 17770           0.0951         0.508491         0.101027         0.491943
# 17771           0.0860         0.239623         0.072401         0.400948
#
#        drtg_max_opp_10  total_opp_10  home_opp_10  season_10
# 1385          0.374118      0.366346          0.5     2016.0
# 1489          0.430588      0.378846          0.5     2016.0
# 1515          0.507059      0.436538          0.5     2017.0
# 1542          0.427059      0.381731          0.7     2019.0
# 1596          0.508235      0.325000          0.6     2016.0
# ...                ...           ...          ...        ...
# 17767         0.456471      0.423077          0.6     2020.0
# 17768         0.492941      0.429808          0.6     2020.0
# 17769         0.536471      0.425000          0.5     2020.0
# 17770         0.372941      0.399038          0.4     2020.0
# 17771         0.497647      0.434615          0.4     2020.0
#
# [15882 rows x 279 columns]

# %%
def shift_col(team, col_name):
    next_col = team[col_name].shift(-1)
    return next_col

def add_col(df, col_name):
    return df.groupby("team", group_keys=False).apply(lambda x: shift_col(x, col_name))

df["home_next"] = add_col(df, "home")
df["team_opp_next"] = add_col(df, "team_opp")
df["date_next"] = add_col(df, "date")
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_22484\1688004556.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby("team", group_keys=False).apply(lambda x: shift_col(x, col_name))
# C:\Users\moham\AppData\Local\Temp\ipykernel_22484\1688004556.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby("team", group_keys=False).apply(lambda x: shift_col(x, col_name))
# C:\Users\moham\AppData\Local\Temp\ipykernel_22484\1688004556.py:6: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   return df.groupby("team", group_keys=False).apply(lambda x: shift_col(x, col_name))

# %%
df
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 1385   0.0  0.477273  0.397059  0.456938  0.344828  0.439394  0.359857
# 1489   0.0  0.204545  0.323529  0.172249  0.310345  0.409091  0.344418
# 1515   0.0  0.454545  0.250000  0.566986  0.482759  0.469697  0.475059
# 1542   0.0  0.386364  0.426471  0.322967  0.448276  0.530303  0.395487
# 1596   0.0  0.545455  0.485294  0.461722  0.275862  0.333333  0.365796
# ...    ...       ...       ...       ...       ...       ...       ...
# 17767  0.0  0.431818  0.308824  0.478469  0.413793  0.393939  0.475059
# 17768  0.0  0.181818  0.117647  0.306220  0.310345  0.348485  0.395487
# 17769  0.0  0.318182  0.279412  0.356459  0.275862  0.363636  0.339667
# 17770  0.5  0.568182  0.602941  0.399522  0.655172  0.651515  0.479810
# 17771  0.5  0.568182  0.588235  0.409091  0.655172  0.636364  0.490499
#
#              ft       fta       ft%  ...  tov%_max_opp_10  usg%_max_opp_10  \
# 1385   0.348837  0.269841  0.870478  ...         0.467925         0.146598
# 1489   0.720930  0.571429  0.842474  ...         0.404088         0.124519
# 1515   0.488372  0.428571  0.750292  ...         0.299895         0.152246
# 1542   0.279070  0.285714  0.631272  ...         0.423166         0.135430
# 1596   0.255814  0.285714  0.570595  ...         0.377254         0.113607
# ...         ...       ...       ...  ...              ...              ...
# 17767  0.302326  0.206349  1.000000  ...         0.525262         0.155199
# 17768  0.488372  0.396825  0.820303  ...         0.451887         0.226444
# 17769  0.488372  0.460317  0.688448  ...         0.385010         0.175610
# 17770  0.395349  0.380952  0.673279  ...         0.508491         0.101027
# 17771  0.325581  0.269841  0.805134  ...         0.239623         0.072401
#
#        ortg_max_opp_10  drtg_max_opp_10  total_opp_10  home_opp_10  season_10  \
# 1385          0.406161         0.374118      0.366346          0.5     2016.0
# 1489          0.559242         0.430588      0.378846          0.5     2016.0
# 1515          0.384834         0.507059      0.436538          0.5     2017.0
# 1542          0.306635         0.427059      0.381731          0.7     2019.0
# 1596          0.356872         0.508235      0.325000          0.6     2016.0
# ...                ...              ...           ...          ...        ...
# 17767         0.373934         0.456471      0.423077          0.6     2020.0
# 17768         0.453555         0.492941      0.429808          0.6     2020.0
# 17769         0.428910         0.536471      0.425000          0.5     2020.0
# 17770         0.491943         0.372941      0.399038          0.4     2020.0
# 17771         0.400948         0.497647      0.434615          0.4     2020.0
#
#        home_next  team_opp_next  date_next
# 1385         0.0            HOU  1/24/2016
# 1489         0.0            SAC  1/25/2016
# 1515         1.0            DAL  1/24/2016
# 1542         0.0            DAL  1/25/2019
# 1596         0.0            MIN  1/25/2020
# ...          ...            ...        ...
# 17767        NaN           None       None
# 17768        NaN           None       None
# 17769        NaN           None       None
# 17770        NaN           None       None
# 17771        NaN           None       None
#
# [15882 rows x 282 columns]

# %%
df = df.copy()

# %%
full = df.merge(df[rolling_cols + ["team_opp_next", "date_next", "team"]], left_on=["team", "date_next"], right_on=["team_opp_next", "date_next"])

# %%
full
# Out:
#         mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      0.0  0.477273  0.397059  0.456938  0.344828  0.439394  0.359857
# 1      0.0  0.454545  0.250000  0.566986  0.482759  0.469697  0.475059
# 2      0.0  0.545455  0.485294  0.461722  0.275862  0.333333  0.365796
# 3      0.0  0.386364  0.279412  0.447368  0.517241  0.393939  0.593824
# 4      0.0  0.363636  0.367647  0.342105  0.241379  0.272727  0.377672
# ...    ...       ...       ...       ...       ...       ...       ...
# 15739  0.0  0.363636  0.264706  0.430622  0.758621  0.742424  0.492874
# 15740  0.0  0.500000  0.220588  0.665072  0.379310  0.409091  0.421615
# 15741  0.0  0.568182  0.500000  0.476077  0.379310  0.454545  0.384798
# 15742  0.0  0.431818  0.250000  0.538278  0.379310  0.454545  0.384798
# 15743  0.0  0.318182  0.367647  0.284689  0.413793  0.545455  0.356295
#
#              ft       fta       ft%  ...  blk%_max_opp_10_y  \
# 0      0.348837  0.269841  0.870478  ...             0.0852
# 1      0.488372  0.428571  0.750292  ...             0.0613
# 2      0.255814  0.285714  0.570595  ...             0.0660
# 3      0.372093  0.333333  0.735123  ...             0.0827
# 4      0.325581  0.301587  0.708285  ...             0.0971
# ...         ...       ...       ...  ...                ...
# 15739  0.372093  0.349206  0.695449  ...             0.0698
# 15740  0.441860  0.396825  0.730455  ...             0.0598
# 15741  0.162791  0.142857  0.766628  ...             0.0832
# 15742  0.534884  0.412698  0.870478  ...             0.1067
# 15743  0.232558  0.190476  0.820303  ...             0.0811
#
#        tov%_max_opp_10_y  usg%_max_opp_10_y  ortg_max_opp_10_y  \
# 0               0.299895           0.152246           0.384834
# 1               0.467925           0.146598           0.406161
# 2               0.512788           0.162516           0.488626
# 3               0.430713           0.140436           0.562559
# 4               0.316771           0.121438           0.396209
# ...                  ...                ...                ...
# 15739           0.344654           0.156226           0.379147
# 15740           0.474319           0.226444           0.453555
# 15741           0.322117           0.174069           0.427962
# 15742           0.510797           0.102824           0.407583
# 15743           0.242558           0.081772           0.472512
#
#        drtg_max_opp_10_y  total_opp_10_y  home_opp_10_y  season_10_y  \
# 0               0.507059        0.436538            0.5       2017.0
# 1               0.374118        0.366346            0.5       2016.0
# 2               0.560000        0.437500            0.5       2018.0
# 3               0.548235        0.457692            0.7       2020.0
# 4               0.508235        0.443269            0.4       2018.0
# ...                  ...             ...            ...          ...
# 15739           0.552941        0.404808            0.3       2020.0
# 15740           0.520000        0.431731            0.6       2020.0
# 15741           0.541176        0.455769            0.4       2020.0
# 15742           0.369412        0.380769            0.4       2020.0
# 15743           0.480000        0.398077            0.5       2020.0
#
#        team_opp_next_y  team_y
# 0                  DAL     HOU
# 1                  HOU     DAL
# 2                  OKC     MIN
# 3                  DAL     LAL
# 4                  ORL     LAC
# ...                ...     ...
# 15739              HOU     LAL
# 15740              LAC     DEN
# 15741              DEN     LAC
# 15742              BOS     TOR
# 15743              TOR     BOS
#
# [15744 rows x 421 columns]

# %%
full[["team_x", "team_opp_next_x", "team_y", "team_opp_next_y", "date_next"]]
# Out:
#       team_x team_opp_next_x team_y team_opp_next_y  date_next
# 0        DAL             HOU    HOU             DAL  1/24/2016
# 1        HOU             DAL    DAL             HOU  1/24/2016
# 2        OKC             MIN    MIN             OKC  1/25/2020
# 3        DAL             LAL    LAL             DAL  1/26/2016
# 4        ORL             LAC    LAC             ORL  1/26/2020
# ...      ...             ...    ...             ...        ...
# 15739    HOU             LAL    LAL             HOU   9/8/2020
# 15740    LAC             DEN    DEN             LAC   9/9/2020
# 15741    DEN             LAC    LAC             DEN   9/9/2020
# 15742    BOS             TOR    TOR             BOS   9/9/2020
# 15743    TOR             BOS    BOS             TOR   9/9/2020
#
# [15744 rows x 5 columns]

# %%
removed_columns = list(full.columns[full.dtypes == "object"]) + removed_columns

# %%
removed_columns
# Out:
# ['team_x',
#  'team_opp',
#  'date',
#  'team_opp_next_x',
#  'date_next',
#  'team_opp_next_y',
#  'team_y',
#  'season',
#  'date',
#  'won',
#  'target',
#  'team',
#  'team_opp']

# %%
selected_columns = full.columns[~full.columns.isin(removed_columns)]
sfs.fit(full[selected_columns], full["target"])
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=RidgeClassifier(alpha=1),
#                           n_features_to_select=30, n_jobs=1)

# %%
predictors = list(selected_columns[sfs.get_support()])

# %%
predictors
# Out:
# ['usg%',
#  'fg%_max',
#  'blk_max',
#  'stl%_max',
#  '3p%_opp',
#  'pf_opp',
#  'ftr_opp',
#  'usg%_opp',
#  'fg%_max_opp',
#  'trb_max_opp',
#  'blk_max_opp',
#  'ts%_max_opp',
#  'ftr_10_x',
#  'blk%_10_x',
#  'usg%_10_x',
#  '3p_max_10_x',
#  'orb%_max_10_x',
#  'fg_opp_10_x',
#  'usg%_opp_10_x',
#  'pts_max_opp_10_x',
#  'ast%_max_opp_10_x',
#  'home_next',
#  'ast_10_y',
#  'usg%_10_y',
#  'fg_max_10_y',
#  'blk_max_10_y',
#  'usg%_opp_10_y',
#  'fga_max_opp_10_y',
#  '+/-_max_opp_10_y',
#  'tov%_max_opp_10_y']

# %%
predictions = backtest(full, rr, predictors)

# %%
accuracy_score(predictions["actual"], predictions["prediction"])
# Out:
# 0.5634082498420435
